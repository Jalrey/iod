# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.1.3
#
# ## Data
#
# The Philippine Statistics Authority (PSA) spearheads the conduct of the Family Income and Expenditure Survey (FIES) nationwide. The survey, which is undertaken every three (3) years, is aimed at providing data on family income and expenditure, including, among others, levels of consumption by item of expenditure, sources of income in cash, and related information affecting income and expenditure levels and patterns in the Philippines.
#
# You can download the data from [here](https://www.kaggle.com/grosvenpaul/family-income-and-expenditure).
#
# The purpose of today's lab is to use simulation to visualize the sampling distribution for the sample mean. The Central Limit Theorem (CLT) tells us that as our sample size gets larger, the sampling distribution of the sample mean converges to a normal distribution. Therefore, when we have a large sample size, we can say that the sampling distribution for the sample mean is approximately normal, regardless of the distribution from which we are sampling.
#
# Let's start by taking a look at the data, **`Total Household Income`** will serve as a "population" for the purposes of this lab.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
house_hold_csv = ".../../Family_Income_and_Expenditure.csv"
# Read CSV

house = pd.read_csv(house_hold_csv)

# %%
# Head
house.head()
# Out:
#    Total Household Income Region  Total Food Expenditure  \
# 0                  480332    CAR                  117848
# 1                  198235    CAR                   67766
# 2                   82785    CAR                   61609
# 3                  107589    CAR                   78189
# 4                  189322    CAR                   94625
#
#   Main Source of Income  Agricultural Household indicator  \
# 0         Wage/Salaries                                 0
# 1         Wage/Salaries                                 0
# 2         Wage/Salaries                                 1
# 3         Wage/Salaries                                 0
# 4         Wage/Salaries                                 0
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# ...

# %%
# Tail
house.tail()
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 41539                  119773  XII - SOCCSKSARGEN                   44875
# 41540                  137320  XII - SOCCSKSARGEN                   31157
# 41541                  133171  XII - SOCCSKSARGEN                   45882
# 41542                  129500  XII - SOCCSKSARGEN                   81416
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# 41539  Enterpreneurial Activities                                 1
# 41540  Enterpreneurial Activities                                 1
# 41541  Enterpreneurial Activities                                 2
# 41542  Enterpreneurial Activities                                 1
# 41543  Enterpreneurial Activities                                 1
#
#        Bread and Cereals Expenditure  Total Rice Expenditure  \
# ...

# %%
# Shape
house.shape
# Out:
# (41544, 60)

# %%
# Data Types
house.dtypes
# Out:
# Total Household Income                            int64
# Region                                           object
# Total Food Expenditure                            int64
# Main Source of Income                            object
# Agricultural Household indicator                  int64
# Bread and Cereals Expenditure                     int64
# Total Rice Expenditure                            int64
# Meat Expenditure                                  int64
# Total Fish and  marine products Expenditure       int64
# Fruit Expenditure                                 int64
# Vegetables Expenditure                            int64
# Restaurant and hotels Expenditure                 int64
# Alcoholic Beverages Expenditure                   int64
# Tobacco Expenditure                               int64
# Clothing, Footwear and Other Wear Expenditure     int64
# Housing and water Expenditure                     int64
# Imputed House Rental Value                        int64
# ...

# %%
#Describe
house.describe()
# Out:
#        Total Household Income  Total Food Expenditure  \
# count            4.154400e+04            41544.000000
# mean             2.475556e+05            85099.158194
# std              2.868805e+05            51637.947682
# min              1.128500e+04             2947.000000
# 25%              1.048950e+05            51017.250000
# 50%              1.640795e+05            72985.500000
# 75%              2.911385e+05           105635.500000
# max              1.181599e+07           827565.000000
#
#        Agricultural Household indicator  Bread and Cereals Expenditure  \
# count                      41544.000000                   41544.000000
# mean                           0.429858                   25133.723642
# std                            0.676666                   13466.482984
# min                            0.000000                       0.000000
# 25%                            0.000000                   16556.000000
# ...

# %%
#Null Values

# %%
house.isnull().sum()
# Out:
# Total Household Income                              0
# Region                                              0
# Total Food Expenditure                              0
# Main Source of Income                               0
# Agricultural Household indicator                    0
# Bread and Cereals Expenditure                       0
# Total Rice Expenditure                              0
# Meat Expenditure                                    0
# Total Fish and  marine products Expenditure         0
# Fruit Expenditure                                   0
# Vegetables Expenditure                              0
# Restaurant and hotels Expenditure                   0
# Alcoholic Beverages Expenditure                     0
# Tobacco Expenditure                                 0
# Clothing, Footwear and Other Wear Expenditure       0
# Housing and water Expenditure                       0
# Imputed House Rental Value                          0
# ...

# %%
house[house['Household Head Occupation'].isnull()]
# Out:
#        Total Household Income              Region  Total Food Expenditure  \
# 8                      171152                 CAR                   67348
# 13                     128214                 CAR                   62262
# 14                      91525                 CAR                   45487
# 15                     171742                 CAR                   70892
# 26                      84330                 CAR                   45509
# ...                       ...                 ...                     ...
# 41520                  695292  XII - SOCCSKSARGEN                  136459
# 41529                   95500  XII - SOCCSKSARGEN                   73138
# 41533                  153500  XII - SOCCSKSARGEN                   70991
# 41535                  166600  XII - SOCCSKSARGEN                   90786
# 41543                  128598  XII - SOCCSKSARGEN                   78195
#
#             Main Source of Income  Agricultural Household indicator  \
# ...

# %% [markdown]
# #### Surveying the populations
#
# ##### 1. Create a histogram of `Total Household Income`.

# %%
# ANSWER
plt.figure(figsize = (15,12))
plt.hist(house['Total Household Income'])
plt.show()

# %% [markdown]
# ##### 2. How would you describe the shape of this population?

# %% [markdown]
# **ANSWER:**

# %%
# This population is heavily skewed to the left

# %% [markdown]
# ##### 2. What is the mean income of this population?

# %%
# ANSWER
print(f"The mean household income is {house['Total Household Income'].mean()}")
# Out:
# The mean household income is 247555.58480165608

# %% [markdown]
# ##### 3. What sampling statistic/point estimate would you use to estimate the mean of this population if you were given a random sample from the population?

# %% [markdown]
# **ANSWER:**

# %% [markdown]
# #### Simulated sampling (sample means)

# %% [markdown]
# Now, we'd like to get an idea of what happens when we take multiple random samples of size 5.
#
# Take 10 sample (size=5) from the entire population. Calculate means for each sample. Now make a histogram of all the sample means.
#
# - Describe the shape of the histogram.
# - What is the center of the distribution of sample means?

# %% [markdown]
# ##### 4. Simulation with `sample_size=5`

# %% [markdown]
# Take 10 samples, but with a sample size of 5.

# %%
# ANSWER
def calculate_sample_mean(df, column_name, N=10, sample_size = 5):
    
    sample_mean_list = []
    
    for i in range(N):
        df_sample = df.sample(n=sample_size)
        sample_mean = df_sample[column_name].mean()
        sample_mean_list.append(sample_mean)
    
    return sample_mean_list

# %%
sample = calculate_sample_mean(house, 'Total Household Income', N=10, sample_size = 5)

sample
# Out:
# [261945.6,
#  153764.6,
#  185229.2,
#  416619.0,
#  103739.6,
#  113136.0,
#  170432.4,
#  361683.0,
#  442829.2,
#  113769.6]

# %% [markdown]
# ###### 4.A Make a histogram of all the sample means

# %%
# ANSWER
plt.hist(sample)
plt.show()

# %% [markdown]
# ###### 4.B Describe the shape of the histogram.

# %% [markdown]
# **ANSWER:**

# %% [markdown]
# ##### 7. Simulation with `sample_size=15`

# %% [markdown]
# let's try taking another 1000 samples, but with a sample size of 15

# %%
# ANSWER
sample2 = calculate_sample_mean(house, 'Total Household Income', N = 1000, sample_size = 15)
plt.hist(sample2)
plt.show()

# %% [markdown]
# ##### 8. Simulation with `sample_size=50`

# %% [markdown]
# Let's try taking another 1000 samples, but with a sample size of 50

# %%
# ANSWER

sample3 = calculate_sample_mean(house, 'Total Household Income', N = 1000, sample_size = 50)
plt.hist(sample2)
plt.show()

# %% [markdown]
# ###### 8.A Describe the shape of the histogram of sample means (using sample size of 50)

# %% [markdown]
# **ANSWER:**

# %%
#The sample size of 50 shows a normal distribution

# %% [markdown]
# ###### 8.B What is mean of the distribution of sample means?

# %%
# ANSWER
print(f" The mean of the distribution of sample is {np.mean(sample3)}")
# Out:
#  The mean of the distribution of sample is 247524.16944

# %% [markdown]
# **ANSWER:**
#
# > If repeated random samples of a given size n are taken from a population of values for a quantitative variable, where the population mean is μ (mu) and the population standard deviation is σ (sigma) then the mean of all sample means (x-bars) is population mean μ (mu).

# %% [markdown]
# ###### 8.C As the sample size grew, did your results confirm the CLT?

# %% [markdown]
# **ANSWER:**

# %%
#Even if the original data set is significantly skewed, if we had enough sample size, we would get a normally distributed result

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2022 Institute of Data
#
#
# ---
#
#
#
# ---
